# %% [markdown]
# # Intro to Python: Exercise 4

# %% [markdown]
# ## Linear regression with one variable

# %% [markdown]
# In the first part of the exercise, we're tasked with implementing linear regression with one variable to predict profits for a food truck. Suppose you are the CEO of a restaurant franchise and are considering different cities for opening a new outlet. The chain already has trucks in various cities and you have data for profits and populations from the cities.

# %% [markdown]
# Let's start by importing some libraries and examining the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# Read the data from the CSV file using Panda library

# %%
# !git clone https://github.com/vita-epfl/DLAV-2026.git
path = os.getcwd() + '/DLAV-2026/homeworks/hw1/data/ex1data1.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])
data.head()
# Out:
# fatal: destination path 'DLAV-2026' already exists and is not an empty directory.
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %% [markdown]
# Let's plot it to get a better idea of what the data looks like.

# %%
data.plot(kind='scatter', x='Population', y='Profit', figsize=(12,8))
# Out:
# <Axes: xlabel='Population', ylabel='Profit'>

# %% [markdown]
# Now let's implement linear regression using gradient descent to minimize the cost function.  The equations implemented in the following code samples are detailed in "ex1.pdf" in the "exercises" folder.

# %% [markdown]
# First we'll create a function to compute the cost of a given solution (characterized by the parameters theta). The cost function is the Mean Sqaured error in matrix form:
#
# $$ MSE(\theta) = \frac{1}{N}\sum_n^N [ y_n-x_n^T*\theta]^2 $$
#
# where $\theta$ and $x_n$ are vectors
#
# __Hint__: Use the matrix form of the cost function and make use of numpy operations.

# %%
def computeCost(x, y, theta):
    # Compute the cost function
    mse = (y - x@theta)@np.transpose(y - x@theta)/len(x)
    return mse

# %% [markdown]
# Let's add a column of ones to the training set so we can use a vectorized solution to computing the cost and gradients.

# %%
data.insert(0, 'Ones', 1)

# %% [markdown]
# Now let's do some variable initialization.

# %%
# set X (training data) and y (target variable)
cols = data.shape[1]
X = data.iloc[:,0:cols-1]
y = data.iloc[:,cols-1:cols]

# %% [markdown]
# Let's take a look to make sure X (training set) and y (target variable) look correct.

# %%
X.head()
# Out:
#    Ones  Population
# 0     1      6.1101
# 1     1      5.5277
# 2     1      8.5186
# 3     1      7.0032
# 4     1      5.8598

# %%
y.head()
# Out:
#     Profit
# 0  17.5920
# 1   9.1302
# 2  13.6620
# 3  11.8540
# 4   6.8233

# %% [markdown]
# Convert X and Y to numpy array for better manipulation. Initiliaze Theta.

# %%
X = np.array(X.values)
y = np.array(y.values).flatten()
theta = np.array([0,0])
theta
# Out:
# array([0, 0])

# %% [markdown]
# Let's take a quick look at the shape of our matrices.

# %%
X.shape, theta.shape, y.shape
# Out:
# ((97, 2), (2,), (97,))

# %% [markdown]
# Now let's compute the cost for our initial solution (0 values for theta).

# %%
computeCost(X, y, theta)
# Out:
# np.float64(64.14546775491135)

# %% [markdown]
# So far so good.  Now we need to define a function to perform gradient descent on the parameters theta using the update rules. Write first a function that computes the gradient of a matrix and then use it in the gradientDescent function.
#
# The gradient descent formula is:
#
# $$\theta^{t+1} = \theta^{t} - \alpha*\nabla MSE(\theta^{t})$$
#
# where $\nabla MSE(\theta^{t})$ is the gradient of the cost function at $\theta^{t}$
#
# __Hint__: Use the matrix form of the gradient and make use of numpy operations.

# %%
def compute_gradient(y, tx, w):
    """Compute the gradient."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: compute gradient and loss
    # ***************************************************
    gradient = (-2 / len(tx)) * tx.T @ (y - tx @ w)
    loss = computeCost(tx,y,w)
    return gradient

# %%
def gradientDescent(X, y, theta, alpha,max_iters):
    """Gradient descent algorithm."""
    # Define parameters to store w and loss
    ws = [theta]
    cost = np.zeros(max_iters)
    for n_iter in range(max_iters):
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: compute gradient and loss
        # ***************************************************
        gradient,loss = compute_gradient(y,X,ws[-1])
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: update theta by gradient
        # ***************************************************
        theta = ws[-1]-alpha*gradient
        # store w and loss
        ws.append(theta)
        cost[n_iter] = loss
        print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=theta[0], w1=theta[1]))

    return theta, cost

# %% [markdown]
# Initialize some additional variables - the learning rate alpha, and the number of iterations to perform.

# %%
alpha = 0.01
iters = 1000

# %% [markdown]
# Now let's run the gradient descent algorithm to fit our parameters theta to the training set.

# %%
g, cost = gradientDescent(X, y, theta, alpha, iters)
g
# Out:
# Gradient Descent(0/999): loss=-130.65769949111342, w0=0.1167827010309278, w1=0.1167827010309278
# Gradient Descent(1/999): loss=-109.7387078887139, w0=0.21217127836379382, w1=0.21217127836379382
# Gradient Descent(2/999): loss=-92.65199187190753, w0=0.2900850498835881, w1=0.2900850498835881
# Gradient Descent(3/999): loss=-78.69549388251608, w0=0.3537253301160421, w1=0.3537253301160421
# Gradient Descent(4/999): loss=-67.29577049878915, w0=0.40570696557103153, w1=0.40570696557103153
# Gradient Descent(5/999): loss=-57.98443084006743, w0=0.44816577333720864, w1=0.44816577333720864
# Gradient Descent(6/999): loss=-50.37889136146495, w0=0.48284629735585316, w1=0.48284629735585316
# Gradient Descent(7/999): loss=-44.16665629318452, w0=0.5111734880963781, w1=0.5111734880963781
# Gradient Descent(8/999): loss=-39.092477840472796, w0=0.5343112508020018, w1=0.5343112508020018
# Gradient Descent(9/999): loss=-34.94786858358404, w0=0.5532102679310061, w1=0.5532102679310061
# Gradient Descent(10/999): loss=-31.562535164120266, w0=0.5686470607180454, w1=0.5686470607180454
# Gradient Descent(11/999): loss=-28.797381285768584, w0=0.5812558948136702, w1=0.5812558948136702
# Gradient Descent(12/999): loss=-26.53879253731541, w0=0.5915548409383129, w1=0.5915548409383129
# Gradient Descent(13/999): loss=-24.693968213223858, w0=0.5999670613287056, w1=0.5999670613287056
# Gradient Descent(14/999): loss=-23.187108326008598, w0=0.6068381965924599, w1=0.6068381965924599
# Gradient Descent(15/999): loss=-21.95629914269164, w0=0.6124505673604355, w1=0.6124505673604355
# Gradient Descent(16/999): loss=-20.95096927852157, w0=0.617034774253201, w1=0.617034774253201
# Gradient Descent(17/999): loss=-20.129811824148028, w0=0.6207791727800394, w1=0.6207791727800394
# Gradient Descent(18/999): loss=-19.459087130785907, w0=0.6238376124743551, w1=0.6238376124743551
# Gradient Descent(19/999): loss=-18.911236518348954, w0=0.626335758250431, w1=0.626335758250431
# Gradient Descent(20/999): loss=-18.463749946707978, w0=0.6283762537129128, w1=0.6283762537129128
# Gradient Descent(21/999): loss=-18.098241125045362, w0=0.6300429385686499, w1=0.6300429385686499
# Gradient Descent(22/999): loss=-17.79969205747605, w0=0.6314042934255554, w1=0.6314042934255554
# Gradient Descent(23/999): loss=-17.555835984889157, w0=0.6325162535180952, w1=0.6325162535180952
# Gradient Descent(24/999): loss=-17.356653369375902, w0=0.633424506969522, w1=0.633424506969522
# Gradient Descent(25/999): loss=-17.19396021229421, w0=0.6341663720216613, w1=0.6341663720216613
# Gradient Descent(26/999): loss=-17.061071790817255, w0=0.6347723303637088, w1=0.6347723303637088
# Gradient Descent(27/999): loss=-16.952527996601187, w0=0.6352672795613267, w1=0.6352672795613267
# Gradient Descent(28/999): loss=-16.863868991310323, w0=0.6356715560457377, w1=0.6356715560457377
# Gradient Descent(29/999): loss=-16.79145196115276, w0=0.6360017706953105, w1=0.6360017706953105
# Gradient Descent(30/999): loss=-16.73230144125191, w0=0.6362714913419403, w1=0.6362714913419403
# Gradient Descent(31/999): loss=-16.683987059994813, w0=0.63649180024499, w1=0.63649180024499
# Gradient Descent(32/999): loss=-16.644523680126515, w0=0.6366717494382366, w1=0.6366717494382366
# Gradient Descent(33/999): loss=-16.612289833596567, w0=0.6368187326590772, w1=0.6368187326590772
# Gradient Descent(34/999): loss=-16.585961098815496, w0=0.6369387891417927, w1=0.6369387891417927
# Gradient Descent(35/999): loss=-16.564455682931396, w0=0.6370368517571007, w1=0.6370368517571007
# Gradient Descent(36/999): loss=-16.54688997321559, w0=0.6371169496935347, w1=0.6371169496935347
# Gradient Descent(37/999): loss=-16.53254223125687, w0=0.6371823740084057, w1=0.6371823740084057
# Gradient Descent(38/999): loss=-16.520822938234048, w0=0.6372358128504897, w1=0.6372358128504897
# Gradient Descent(39/999): loss=-16.511250572815804, w0=0.6372794619104593, w1=0.6372794619104593
# Gradient Descent(40/999): loss=-16.50343182645272, w0=0.6373151146372386, w1=0.6373151146372386
# Gradient Descent(41/999): loss=-16.49704544314839, w0=0.6373442359270828, w1=0.6373442359270828
# Gradient Descent(42/999): loss=-16.491829019719876, w0=0.6373680223131127, w1=0.6373680223131127
# Gradient Descent(43/999): loss=-16.487568224197776, w0=0.6373874511283676, w1=0.6373874511283676
# Gradient Descent(44/999): loss=-16.484087989372124, w0=0.637403320662383, w1=0.637403320662383
# Gradient Descent(45/999): loss=-16.481245319645605, w0=0.637416282961245, w1=0.637416282961245
# Gradient Descent(46/999): loss=-16.478923415642292, w0=0.6374268706188045, w1=0.6374268706188045
# Gradient Descent(47/999): loss=-16.477026875164793, w0=0.6374355186598498, w1=0.6374355186598498
# Gradient Descent(48/999): loss=-16.475477773316605, w0=0.6374425824143678, w1=0.6374425824143678
# Gradient Descent(49/999): loss=-16.474212460730588, w0=0.6374483521173131, w1=0.6374483521173131
# Gradient Descent(50/999): loss=-16.47317894834909, w0=0.6374530648337576, w1=0.6374530648337576
# Gradient Descent(51/999): loss=-16.472334771301824, w0=0.6374569141994004, w1=0.6374569141994004
# Gradient Descent(52/999): loss=-16.471645244112892, w0=0.6374600583766549, w1=0.6374600583766549
# Gradient Descent(53/999): loss=-16.4710820355469, w0=0.6374626265532131, w1=0.6374626265532131
# Gradient Descent(54/999): loss=-16.47062200453734, w0=0.6374647242500985, w1=0.6374647242500985
# Gradient Descent(55/999): loss=-16.470246249368603, w0=0.6374664376573053, w1=0.6374664376573053
# Gradient Descent(56/999): loss=-16.469939331043772, w0=0.6374678371751654, w1=0.6374678371751654
# Gradient Descent(57/999): loss=-16.469688638928368, w0=0.6374689803069516, w1=0.6374689803069516
# Gradient Descent(58/999): loss=-16.46948387260574, w0=0.6374699140215672, w1=0.6374699140215672
# Gradient Descent(59/999): loss=-16.469316618654357, w0=0.6374706766834, w1=0.6374706766834
# Gradient Descent(60/999): loss=-16.469180004957842, w0=0.6374712996286357, w1=0.6374712996286357
# Gradient Descent(61/999): loss=-16.46906841834408, w0=0.6374718084527959, w1=0.6374718084527959
# Gradient Descent(62/999): loss=-16.468977273951616, w0=0.6374722240624053, w1=0.6374722240624053
# Gradient Descent(63/999): loss=-16.468902826847273, w0=0.6374725635339967, w1=0.6374725635339967
# Gradient Descent(64/999): loss=-16.468842018154664, w0=0.6374728408157505, w1=0.6374728408157505
# Gradient Descent(65/999): loss=-16.468792349371295, w0=0.6374730673005962, w1=0.6374730673005962
# Gradient Descent(66/999): loss=-16.468751779710352, w0=0.6374732522943239, w1=0.6374732522943239
# Gradient Descent(67/999): loss=-16.468718642249026, w0=0.6374734033979408, w1=0.6374734033979408
# Gradient Descent(68/999): loss=-16.468691575438086, w0=0.6374735268199795, w1=0.6374735268199795
# Gradient Descent(69/999): loss=-16.46866946715862, w0=0.6374736276315943, w1=0.6374736276315943
# Gradient Descent(70/999): loss=-16.468651409027526, w0=0.6374737099749246, w1=0.6374737099749246
# Gradient Descent(71/999): loss=-16.468636659073812, w0=0.6374737772332861, w1=0.6374737772332861
# Gradient Descent(72/999): loss=-16.46862461125263, w0=0.6374738321701849, w1=0.6374738321701849
# Gradient Descent(73/999): loss=-16.468614770544068, w0=0.6374738770428636, w1=0.6374738770428636
# Gradient Descent(74/999): loss=-16.468606732613964, w0=0.637473913695047, w1=0.637473913695047
# Gradient Descent(75/999): loss=-16.468600167200513, w0=0.637473943632697, w1=0.637473943632697
# Gradient Descent(76/999): loss=-16.468594804544527, w0=0.6374739680858893, w1=0.6374739680858893
# Gradient Descent(77/999): loss=-16.468590424305685, w0=0.6374739880593545, w1=0.6374739880593545
# Gradient Descent(78/999): loss=-16.468586846509087, w0=0.6374740043737608, w1=0.6374740043737608
# Gradient Descent(79/999): loss=-16.468583924150515, w0=0.6374740176994331, w1=0.6374740176994331
# Gradient Descent(80/999): loss=-16.468581537156336, w0=0.6374740285838956, w1=0.6374740285838956
# Gradient Descent(81/999): loss=-16.46857958744994, w0=0.637474037474368, w1=0.637474037474368
# Gradient Descent(82/999): loss=-16.468577994921965, w0=0.6374740447361416, w1=0.6374740447361416
# Gradient Descent(83/999): loss=-16.468576694138736, w0=0.6374740506675872, w1=0.6374740506675872
# Gradient Descent(84/999): loss=-16.46857563165378, w0=0.6374740555124158, w1=0.6374740555124158
# Gradient Descent(85/999): loss=-16.46857476381182, w0=0.637474059469691, w1=0.637474059469691
# Gradient Descent(86/999): loss=-16.468574054955052, w0=0.6374740627020093, w1=0.6374740627020093
# Gradient Descent(87/999): loss=-16.46857347595801, w0=0.6374740653421799, w1=0.6374740653421799
# Gradient Descent(88/999): loss=-16.468573003030897, w0=0.6374740674986817, w1=0.6374740674986817
# Gradient Descent(89/999): loss=-16.468572616742133, w0=0.6374740692601211, w1=0.6374740692601211
# Gradient Descent(90/999): loss=-16.46857230121994, w0=0.6374740706988717, w1=0.6374740706988717
# Gradient Descent(91/999): loss=-16.468572043500146, w0=0.637474071874049, w1=0.637474071874049
# Gradient Descent(92/999): loss=-16.468571832993604, w0=0.6374740728339385, w1=0.6374740728339385
# Gradient Descent(93/999): loss=-16.468571661051005, w0=0.6374740736179801, w1=0.6374740736179801
# Gradient Descent(94/999): loss=-16.468571520607604, w0=0.6374740742583885, w1=0.6374740742583885
# Gradient Descent(95/999): loss=-16.468571405892845, w0=0.6374740747814767, w1=0.6374740747814767
# Gradient Descent(96/999): loss=-16.468571312193394, w0=0.6374740752087371, w1=0.6374740752087371
# Gradient Descent(97/999): loss=-16.4685712356593, w0=0.6374740755577252, w1=0.6374740755577252
# Gradient Descent(98/999): loss=-16.46857117314595, w0=0.6374740758427799, w1=0.6374740758427799
# Gradient Descent(99/999): loss=-16.468571122084803, w0=0.6374740760756139, w1=0.6374740760756139
# Gradient Descent(100/999): loss=-16.468571080377842, w0=0.6374740762657936, w1=0.6374740762657936
# Gradient Descent(101/999): loss=-16.46857104631144, w0=0.6374740764211331, w1=0.6374740764211331
# Gradient Descent(102/999): loss=-16.468571018485868, w0=0.637474076548015, w1=0.637474076548015
# Gradient Descent(103/999): loss=-16.468570995757823, w0=0.6374740766516527, w1=0.6374740766516527
# Gradient Descent(104/999): loss=-16.46857097719347, w0=0.6374740767363043, w1=0.6374740767363043
# Gradient Descent(105/999): loss=-16.46857096203004, w0=0.6374740768054481, w1=0.6374740768054481
# Gradient Descent(106/999): loss=-16.468570949644473, w0=0.637474076861925, w1=0.637474076861925
# Gradient Descent(107/999): loss=-16.468570939527908, w0=0.6374740769080557, w1=0.6374740769080557
# Gradient Descent(108/999): loss=-16.46857093126464, w0=0.6374740769457353, w1=0.6374740769457353
# Gradient Descent(109/999): loss=-16.468570924515184, w0=0.6374740769765123, w1=0.6374740769765123
# Gradient Descent(110/999): loss=-16.468570919002193, w0=0.6374740770016509, w1=0.6374740770016509
# Gradient Descent(111/999): loss=-16.468570914499164, w0=0.6374740770221843, w1=0.6374740770221843
# Gradient Descent(112/999): loss=-16.46857091082108, w0=0.6374740770389561, w1=0.6374740770389561
# Gradient Descent(113/999): loss=-16.46857090781679, w0=0.6374740770526554, w1=0.6374740770526554
# Gradient Descent(114/999): loss=-16.468570905362867, w0=0.637474077063845, w1=0.637474077063845
# Gradient Descent(115/999): loss=-16.46857090335851, w0=0.6374740770729846, w1=0.6374740770729846
# Gradient Descent(116/999): loss=-16.46857090172132, w0=0.63747407708045, w1=0.63747407708045
# Gradient Descent(117/999): loss=-16.46857090038408, w0=0.6374740770865477, w1=0.6374740770865477
# Gradient Descent(118/999): loss=-16.468570899291816, w0=0.6374740770915284, w1=0.6374740770915284
# Gradient Descent(119/999): loss=-16.46857089839964, w0=0.6374740770955966, w1=0.6374740770955966
# Gradient Descent(120/999): loss=-16.468570897670922, w0=0.6374740770989195, w1=0.6374740770989195
# Gradient Descent(121/999): loss=-16.468570897075697, w0=0.6374740771016336, w1=0.6374740771016336
# Gradient Descent(122/999): loss=-16.46857089658951, w0=0.6374740771038506, w1=0.6374740771038506
# Gradient Descent(123/999): loss=-16.46857089619238, w0=0.6374740771056614, w1=0.6374740771056614
# Gradient Descent(124/999): loss=-16.468570895868023, w0=0.6374740771071404, w1=0.6374740771071404
# Gradient Descent(125/999): loss=-16.468570895603083, w0=0.6374740771083486, w1=0.6374740771083486
# Gradient Descent(126/999): loss=-16.468570895386677, w0=0.6374740771093353, w1=0.6374740771093353
# Gradient Descent(127/999): loss=-16.468570895209925, w0=0.6374740771101414, w1=0.6374740771101414
# Gradient Descent(128/999): loss=-16.468570895065547, w0=0.6374740771107997, w1=0.6374740771107997
# Gradient Descent(129/999): loss=-16.46857089494761, w0=0.6374740771113375, w1=0.6374740771113375
# Gradient Descent(130/999): loss=-16.468570894851275, w0=0.6374740771117767, w1=0.6374740771117767
# Gradient Descent(131/999): loss=-16.468570894772597, w0=0.6374740771121356, w1=0.6374740771121356
# Gradient Descent(132/999): loss=-16.468570894708325, w0=0.6374740771124286, w1=0.6374740771124286
# Gradient Descent(133/999): loss=-16.468570894655823, w0=0.637474077112668, w1=0.637474077112668
# Gradient Descent(134/999): loss=-16.46857089461296, w0=0.6374740771128635, w1=0.6374740771128635
# Gradient Descent(135/999): loss=-16.46857089457793, w0=0.6374740771130232, w1=0.6374740771130232
# Gradient Descent(136/999): loss=-16.46857089454933, w0=0.6374740771131536, w1=0.6374740771131536
# Gradient Descent(137/999): loss=-16.46857089452596, w0=0.6374740771132602, w1=0.6374740771132602
# Gradient Descent(138/999): loss=-16.468570894506872, w0=0.6374740771133472, w1=0.6374740771133472
# Gradient Descent(139/999): loss=-16.46857089449129, w0=0.6374740771134183, w1=0.6374740771134183
# Gradient Descent(140/999): loss=-16.468570894478557, w0=0.6374740771134764, w1=0.6374740771134764
# Gradient Descent(141/999): loss=-16.46857089446815, w0=0.6374740771135238, w1=0.6374740771135238
# Gradient Descent(142/999): loss=-16.46857089445966, w0=0.6374740771135625, w1=0.6374740771135625
# Gradient Descent(143/999): loss=-16.468570894452718, w0=0.6374740771135942, w1=0.6374740771135942
# Gradient Descent(144/999): loss=-16.46857089444705, w0=0.63747407711362, w1=0.63747407711362
# Gradient Descent(145/999): loss=-16.46857089444242, w0=0.6374740771136411, w1=0.6374740771136411
# Gradient Descent(146/999): loss=-16.468570894438653, w0=0.6374740771136583, w1=0.6374740771136583
# Gradient Descent(147/999): loss=-16.468570894435555, w0=0.6374740771136724, w1=0.6374740771136724
# Gradient Descent(148/999): loss=-16.468570894433032, w0=0.637474077113684, w1=0.637474077113684
# Gradient Descent(149/999): loss=-16.468570894430957, w0=0.6374740771136934, w1=0.6374740771136934
# Gradient Descent(150/999): loss=-16.46857089442927, w0=0.6374740771137011, w1=0.6374740771137011
# Gradient Descent(151/999): loss=-16.46857089442791, w0=0.6374740771137073, w1=0.6374740771137073
# Gradient Descent(152/999): loss=-16.46857089442679, w0=0.6374740771137124, w1=0.6374740771137124
# Gradient Descent(153/999): loss=-16.46857089442587, w0=0.6374740771137166, w1=0.6374740771137166
# Gradient Descent(154/999): loss=-16.46857089442511, w0=0.6374740771137201, w1=0.6374740771137201
# Gradient Descent(155/999): loss=-16.46857089442449, w0=0.6374740771137228, w1=0.6374740771137228
# Gradient Descent(156/999): loss=-16.468570894424005, w0=0.6374740771137251, w1=0.6374740771137251
# Gradient Descent(157/999): loss=-16.468570894423607, w0=0.637474077113727, w1=0.637474077113727
# Gradient Descent(158/999): loss=-16.468570894423262, w0=0.6374740771137285, w1=0.6374740771137285
# Gradient Descent(159/999): loss=-16.468570894422996, w0=0.6374740771137297, w1=0.6374740771137297
# Gradient Descent(160/999): loss=-16.468570894422776, w0=0.6374740771137307, w1=0.6374740771137307
# Gradient Descent(161/999): loss=-16.468570894422587, w0=0.6374740771137315, w1=0.6374740771137315
# Gradient Descent(162/999): loss=-16.468570894422438, w0=0.6374740771137322, w1=0.6374740771137322
# Gradient Descent(163/999): loss=-16.468570894422328, w0=0.6374740771137327, w1=0.6374740771137327
# Gradient Descent(164/999): loss=-16.46857089442224, w0=0.6374740771137332, w1=0.6374740771137332
# Gradient Descent(165/999): loss=-16.46857089442216, w0=0.6374740771137335, w1=0.6374740771137335
# Gradient Descent(166/999): loss=-16.4685708944221, w0=0.6374740771137338, w1=0.6374740771137338
# Gradient Descent(167/999): loss=-16.46857089442204, w0=0.637474077113734, w1=0.637474077113734
# Gradient Descent(168/999): loss=-16.468570894421998, w0=0.6374740771137343, w1=0.6374740771137343
# Gradient Descent(169/999): loss=-16.468570894421948, w0=0.6374740771137345, w1=0.6374740771137345
# Gradient Descent(170/999): loss=-16.468570894421905, w0=0.6374740771137346, w1=0.6374740771137346
# Gradient Descent(171/999): loss=-16.46857089442188, w0=0.6374740771137347, w1=0.6374740771137347
# Gradient Descent(172/999): loss=-16.468570894421866, w0=0.6374740771137348, w1=0.6374740771137348
# Gradient Descent(173/999): loss=-16.468570894421852, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(174/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(175/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(176/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(177/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(178/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(179/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(180/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(181/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(182/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(183/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(184/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(185/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(186/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(187/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(188/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(189/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(190/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(191/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(192/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(193/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(194/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(195/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(196/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(197/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(198/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(199/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(200/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(201/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(202/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(203/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(204/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(205/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(206/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(207/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(208/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(209/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(210/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(211/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(212/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(213/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(214/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(215/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(216/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(217/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(218/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(219/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(220/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(221/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(222/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(223/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(224/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(225/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(226/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(227/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(228/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(229/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(230/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(231/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(232/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(233/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(234/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(235/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(236/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(237/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(238/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(239/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(240/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(241/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(242/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(243/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(244/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(245/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(246/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(247/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(248/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(249/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(250/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(251/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(252/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(253/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(254/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(255/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(256/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(257/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(258/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(259/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(260/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(261/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(262/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(263/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(264/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(265/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(266/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(267/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(268/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(269/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(270/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(271/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(272/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(273/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(274/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(275/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(276/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(277/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(278/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(279/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(280/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(281/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(282/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(283/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(284/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(285/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(286/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(287/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(288/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(289/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(290/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(291/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(292/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(293/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(294/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(295/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(296/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(297/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(298/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(299/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(300/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(301/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(302/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(303/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(304/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(305/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(306/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(307/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(308/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(309/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(310/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(311/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(312/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(313/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(314/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(315/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(316/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(317/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(318/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(319/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(320/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(321/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(322/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(323/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(324/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(325/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(326/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(327/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(328/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(329/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(330/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(331/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(332/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(333/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(334/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(335/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(336/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(337/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(338/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(339/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(340/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(341/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(342/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(343/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(344/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(345/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(346/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(347/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(348/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(349/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(350/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(351/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(352/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(353/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(354/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(355/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(356/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(357/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(358/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(359/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(360/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(361/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(362/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(363/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(364/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(365/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(366/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(367/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(368/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(369/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(370/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(371/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(372/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(373/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(374/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(375/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(376/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(377/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(378/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(379/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(380/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(381/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(382/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(383/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(384/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(385/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(386/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(387/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(388/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(389/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(390/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(391/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(392/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(393/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(394/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(395/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(396/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(397/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(398/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(399/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(400/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(401/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(402/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(403/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(404/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(405/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(406/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(407/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(408/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(409/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(410/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(411/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(412/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(413/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(414/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(415/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(416/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(417/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(418/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(419/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(420/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(421/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(422/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(423/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(424/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(425/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(426/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(427/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(428/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(429/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(430/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(431/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(432/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(433/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(434/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(435/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(436/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(437/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(438/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(439/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(440/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(441/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(442/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(443/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(444/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(445/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(446/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(447/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(448/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(449/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(450/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(451/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(452/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(453/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(454/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(455/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(456/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(457/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(458/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(459/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(460/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(461/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(462/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(463/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(464/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(465/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(466/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(467/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(468/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(469/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(470/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(471/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(472/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(473/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(474/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(475/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(476/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(477/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(478/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(479/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(480/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(481/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(482/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(483/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(484/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(485/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(486/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(487/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(488/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(489/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(490/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(491/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# ...
# Gradient Descent(838/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(839/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(840/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(841/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(842/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(843/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(844/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(845/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(846/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(847/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(848/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(849/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(850/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(851/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(852/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(853/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(854/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(855/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(856/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(857/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(858/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(859/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(860/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(861/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(862/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(863/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(864/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(865/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(866/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(867/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(868/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(869/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(870/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(871/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(872/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(873/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(874/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(875/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(876/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(877/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(878/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(879/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(880/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(881/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(882/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(883/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(884/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(885/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(886/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(887/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(888/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(889/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(890/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(891/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(892/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(893/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(894/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(895/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(896/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(897/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(898/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(899/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(900/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(901/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(902/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(903/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(904/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(905/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(906/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(907/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(908/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(909/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(910/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(911/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(912/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(913/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(914/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(915/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(916/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(917/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(918/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(919/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(920/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(921/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(922/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(923/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(924/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(925/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(926/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(927/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(928/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(929/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(930/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(931/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(932/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(933/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(934/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(935/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(936/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(937/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(938/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(939/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(940/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(941/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(942/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(943/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(944/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(945/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(946/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(947/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(948/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(949/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(950/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(951/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(952/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(953/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(954/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(955/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(956/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(957/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(958/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(959/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(960/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(961/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(962/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(963/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(964/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(965/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(966/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(967/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(968/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(969/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(970/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(971/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(972/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(973/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(974/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(975/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(976/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(977/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(978/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(979/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(980/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(981/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(982/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(983/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(984/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(985/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(986/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(987/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(988/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(989/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(990/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(991/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(992/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(993/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(994/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(995/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(996/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(997/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(998/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# Gradient Descent(999/999): loss=-16.468570894421827, w0=0.6374740771137349, w1=0.6374740771137349
# array([0.63747408, 0.63747408])

# %% [markdown]
# Finally we can compute the cost (error) of the trained model using our fitted parameters.

# %%
computeCost(X, y, g)
# Out:
# np.float64(13.52857881018189)

# %% [markdown]
# Now let's plot the linear model along with the data to visually see how well it fits.

# %%
x = np.linspace(data.Population.min(), data.Population.max(), 100)
f = g[0] + (g[1] * x)

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(data.Population, data.Profit, label='Traning Data')
ax.legend(loc=2)
ax.set_xlabel('Population')
ax.set_ylabel('Profit')
ax.set_title('Predicted Profit vs. Population Size')
# Out:
# Text(0.5, 1.0, 'Predicted Profit vs. Population Size')

# %% [markdown]
# Looks pretty good!  Since the gradient decent function also outputs a vector with the cost at each training iteration, we can plot that as well.  Notice that the cost always decreases - this is an example of a convex optimization problem.

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(np.arange(iters), cost, 'r')
ax.set_xlabel('Iterations')
ax.set_ylabel('Cost')
ax.set_title('Error vs. Training Epoch')
# Out:
# Text(0.5, 1.0, 'Error vs. Training Epoch')
